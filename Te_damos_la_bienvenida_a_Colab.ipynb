# %% [markdown]
# <a href="https://colab.research.google.com/github/isabelpalaciojara-dot/APY-2026/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
import numpy as np

# %%
brigadas = np.array([[["Juan" , "Antonio", "Ricardo"], ["Alonso", "Jorge" , "Salvador"]],
                     [["David", "Julian", "Ricardo"], [ "Arturo", "Ramiro", "Esteban"]],
                     [["Arturo", "Ricardo", "lucio"],[ "Jorge", "Marco", "Juan"]],
                     [["Alonso", "Julian", "Salvador"],[ "Ricardo", "Jorge", "Esteban"]],
                     [["Lucio", "Ramiro", "Joaquin"],[ "Ricardo", "Marco", "Juan"]]])

# %%
sustitutos = np.array ([["john", Ringo", "Paul"],
["Kevin", "Alonso", "Charlie"]])
# Out:
#   File "/tmp/ipykernel_14508/2192260979.py", line 1
#     sustitutos = np.array ([["john", Ringo", "Paul"],
#                                                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
brigadas[4,1,2] = "Pascual"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14508/553662990.py in <cell line: 0>()
# ----> 1 brigadas[4,1,2] = "Pascual"
#
# NameError: name 'brigadas' is not defined

# %%
matriz_1 = np.array([[1,2,3],
                   [4,0,-5],
                   [-6, -7, -8]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14508/4065265197.py in <cell line: 0>()
# ----> 1 matriz_1 = np.array([[1,2,3],
#       2                    [4,0,-5],
#       3                    [-6, -7, -8]])
#
# NameError: name 'np' is not defined

# %%
matriz_1 + 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14508/2789244900.py in <cell line: 0>()
# ----> 1 matriz_1 + 100
#
# NameError: name 'matriz_1' is not defined

# %%
matriz

# %%
3/ matriz_1

# %% [markdown]
# matriz_2 = [1,2,3]

# %%
matriz_2.shape

# %%
matriz_2 =[1,2,3]

# %%
matriz_1 * matriz_2

# %%
matriz_3 = [2,4,6]

# %%
matriz_3.shape

# %%
matriz_3 * matriz_1

# %%
import numpy as np
arreglo_2 = np.array([])

# %%
arreglo_2.shape

# %%
arreglo_2.reshape(6,2)

# %%
arreglo-2.reshape(12)

# %%
arreglo_2. reshape

# %%
arreglo_3 = np.array([[]])

# %%
arreglo_3.resize(3,3,2)
